# %%
import os
import numpy as np
import pandas as pd
import tqdm
import pickle

# %%
# Load Training Data (X)
import zipfile
# Path to your ZIP archive
zip_path = r"/Users/inan/Documents/GitHub/DIEF_BTS/data/train_X_v0.1.0.zip"
X_train_list = []
seq_len = 336
with zipfile.ZipFile(zip_path, 'r') as z:
    file_list = z.namelist()
    # Filter for .pkl files directly
    pkl_files = [f for f in file_list if f.endswith('.pkl')]
    for pickle_file_name in pkl_files:
        with z.open(pickle_file_name) as f:
            data = pickle.load(f)
            data = data["v"]
            if len(data) >= seq_len:
                data = data[:seq_len]
            else:
                data = np.pad(data, (0, (seq_len - len(data))), mode='constant', constant_values=0)
        X_train_list.append(data)

# Stack them into a 2D array: shape will be (num_samples, 336)
X_train = np.stack(X_train_list, axis=0)

# %%
print(X_train.shape)
# Out:
# (31839, 336)

# %%
y_train_path = "/Users/inan/Documents/GitHub/DIEF_BTS/data/train_y_v0.1.0.csv"
# - A number of target columns that we need to predict for the test set.
df_train_y = pd.read_csv(y_train_path, index_col=0)

# %%
df_train_y = df_train_y.replace({0: 1, -1: 0})

# %%
df_train_y.head()
# Out:
#               Active_Power_Sensor  Air_Flow_Sensor  Air_Flow_Setpoint  \
# filename
# train_X0.pkl                    0                0                  0
# train_X1.pkl                    0                0                  0
# train_X2.pkl                    0                0                  0
# train_X3.pkl                    1                0                  0
# train_X4.pkl                    0                0                  0
#
#               Air_Temperature_Sensor  Air_Temperature_Setpoint  Alarm  \
# filename
# train_X0.pkl                       0                         0      0
# train_X1.pkl                       0                         0      0
# train_X2.pkl                       0                         0      0
# train_X3.pkl                       0                         0      0
# train_X4.pkl                       0                         0      0
#
#               Angle_Sensor  Average_Zone_Air_Temperature_Sensor  \
# filename
# train_X0.pkl             0                                    0
# train_X1.pkl             0                                    0
# train_X2.pkl             0                                    0
# train_X3.pkl             0                                    0
# train_X4.pkl             0                                    0
#
#               Chilled_Water_Differential_Temperature_Sensor  \
# filename
# train_X0.pkl                                              0
# train_X1.pkl                                              0
# train_X2.pkl                                              0
# train_X3.pkl                                              0
# train_X4.pkl                                              0
#
#               Chilled_Water_Return_Temperature_Sensor  ...  \
# filename                                               ...
# train_X0.pkl                                        0  ...
# train_X1.pkl                                        0  ...
# train_X2.pkl                                        0  ...
# train_X3.pkl                                        0  ...
# train_X4.pkl                                        0  ...
#
#               Warmest_Zone_Air_Temperature_Sensor  Water_Flow_Sensor  \
# filename
# train_X0.pkl                                    0                  0
# train_X1.pkl                                    0                  0
# train_X2.pkl                                    0                  0
# train_X3.pkl                                    0                  0
# train_X4.pkl                                    0                  0
#
#               Water_Temperature_Sensor  Water_Temperature_Setpoint  \
# filename
# train_X0.pkl                         0                           0
# train_X1.pkl                         0                           0
# train_X2.pkl                         0                           0
# train_X3.pkl                         0                           0
# train_X4.pkl                         0                           0
#
#               Wind_Direction_Sensor  Wind_Speed_Sensor  \
# filename
# train_X0.pkl                      0                  0
# train_X1.pkl                      0                  0
# train_X2.pkl                      0                  0
# train_X3.pkl                      0                  0
# train_X4.pkl                      0                  0
#
#               Zone_Air_Dewpoint_Sensor  Zone_Air_Humidity_Sensor  \
# filename
# train_X0.pkl                         0                         0
# train_X1.pkl                         0                         0
# train_X2.pkl                         0                         0
# train_X3.pkl                         0                         0
# train_X4.pkl                         0                         0
#
#               Zone_Air_Humidity_Setpoint  Zone_Air_Temperature_Sensor
# filename
# train_X0.pkl                           0                            0
# train_X1.pkl                           0                            0
# train_X2.pkl                           0                            0
# train_X3.pkl                           0                            0
# train_X4.pkl                           0                            0
#
# [5 rows x 94 columns]

# %%
y_train = df_train_y.to_numpy()

# %%
from sklearn.linear_model import RidgeClassifier, LogisticRegression, RidgeClassifierCV
from sklearn.multiclass import OneVsRestClassifier
from sktime.transformations.panel.rocket import (
    MiniRocket,
    MiniRocketMultivariate,
    MiniRocketMultivariateVariable,
    Rocket
)
from sklearn.preprocessing import StandardScaler

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
minirocket = MiniRocket()  # by default, MiniRocket uses ~10_000 kernels
minirocket.fit(X_train)
X_train_transform = minirocket.transform(X_train)
scaler = StandardScaler(with_mean=False)

# %%
# Build a One-vs-Rest multi-label classifier using RidgeClassifier as the base estimator
classifier = OneVsRestClassifier(RidgeClassifier())
X_train_scaled_transform = scaler.fit_transform(X_train_transform)
classifier.fit(X_train_scaled_transform, y_train)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Prediction on Test Data

# %%
# Load Testing Data (X)
import zipfile
# Path to your ZIP archive
zip_path = r"/Users/inan/Documents/GitHub/DIEF_BTS/data/test_X_v0.1.0.zip"
X_test_list = []
seq_len = 336
with zipfile.ZipFile(zip_path, 'r') as z:
    file_list = z.namelist()
    # Filter for .pkl files directly
    pkl_files = [f for f in file_list if f.endswith('.pkl')]
    for pickle_file_name in pkl_files:
        with z.open(pickle_file_name) as f:
            data = pickle.load(f)
            data = data["v"]
            if len(data) >= seq_len:
                data = data[:seq_len]
            else:
                data = np.pad(data, (0, (seq_len - len(data))), mode='constant', constant_values=0)
        X_test_list.append(data)

# Stack them into a 2D array: shape will be (num_samples, 336)
X_test = np.stack(X_test_list, axis=0)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
X_test_transform = minirocket.transform(X_test)
X_test_scaled_transform = scaler.transform(X_test_transform)
predictions = classifier.predict(X_test_scaled_transform)

# %%
# Ensure that the data files (ZIP of test inputs and the train_y file) are placed in the `data` folder.
zip_file_path = r"/Users/inan/Documents/GitHub/DIEF_BTS/data/test_X_v0.1.0.zip"
# Extract all columns except 'filename'—these are our target columns.
expected_columns = list(df_train_y.columns)
filtered_columns = sorted([col for col in expected_columns if col not in ['filename']])

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Get the complete list of files inside the ZIP.
    file_list = zip_ref.namelist()

# Filter the list to only include '.pkl' files and remove the leading directory prefix.
filenames = [f.replace("test_X/", "") for f in file_list if f.endswith('.pkl')]
# -----------------------------------------------------------
# CREATE THE SUBMISSION DATAFRAME
# -----------------------------------------------------------
# Construct a DataFrame with the same structure as the expected submission.
# It must contain a 'filename' column plus one column for each target.

df_sample = pd.DataFrame(predictions, columns=filtered_columns)
df_sample.insert(0, 'filename', filenames)  # Insert 'filename' as the first column.

# %%
# Convert specified columns to float
df_sample[filtered_columns] = df_sample[filtered_columns].astype(np.float16)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315720 entries, 0 to 315719
# Data columns (total 95 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   filename                                             315720 non-null  object
#  1   Active_Power_Sensor                                  315720 non-null  float16
#  2   Air_Flow_Sensor                                      315720 non-null  float16
#  3   Air_Flow_Setpoint                                    315720 non-null  float16
#  4   Air_Temperature_Sensor                               315720 non-null  float16
#  5   Air_Temperature_Setpoint                             315720 non-null  float16
#  6   Alarm                                                315720 non-null  float16
#  7   Angle_Sensor                                         315720 non-null  float16
#  8   Average_Zone_Air_Temperature_Sensor                  315720 non-null  float16
#  9   Chilled_Water_Differential_Temperature_Sensor        315720 non-null  float16
#  10  Chilled_Water_Return_Temperature_Sensor              315720 non-null  float16
#  11  Chilled_Water_Supply_Flow_Sensor                     315720 non-null  float16
#  12  Chilled_Water_Supply_Temperature_Sensor              315720 non-null  float16
#  13  Command                                              315720 non-null  float16
#  14  Cooling_Demand_Sensor                                315720 non-null  float16
#  15  Cooling_Demand_Setpoint                              315720 non-null  float16
#  16  Cooling_Supply_Air_Temperature_Deadband_Setpoint     315720 non-null  float16
#  17  Cooling_Temperature_Setpoint                         315720 non-null  float16
#  18  Current_Sensor                                       315720 non-null  float16
#  19  Damper_Position_Sensor                               315720 non-null  float16
#  20  Damper_Position_Setpoint                             315720 non-null  float16
#  21  Demand_Sensor                                        315720 non-null  float16
#  22  Dew_Point_Setpoint                                   315720 non-null  float16
#  23  Differential_Pressure_Sensor                         315720 non-null  float16
#  24  Differential_Pressure_Setpoint                       315720 non-null  float16
#  25  Differential_Supply_Return_Water_Temperature_Sensor  315720 non-null  float16
#  26  Discharge_Air_Dewpoint_Sensor                        315720 non-null  float16
#  27  Discharge_Air_Temperature_Sensor                     315720 non-null  float16
#  28  Discharge_Air_Temperature_Setpoint                   315720 non-null  float16
#  29  Discharge_Water_Temperature_Sensor                   315720 non-null  float16
#  30  Duration_Sensor                                      315720 non-null  float16
#  31  Electrical_Power_Sensor                              315720 non-null  float16
#  32  Energy_Usage_Sensor                                  315720 non-null  float16
#  33  Filter_Differential_Pressure_Sensor                  315720 non-null  float16
#  34  Flow_Sensor                                          315720 non-null  float16
#  35  Flow_Setpoint                                        315720 non-null  float16
#  36  Frequency_Sensor                                     315720 non-null  float16
#  37  Heating_Demand_Sensor                                315720 non-null  float16
#  38  Heating_Demand_Setpoint                              315720 non-null  float16
#  39  Heating_Supply_Air_Temperature_Deadband_Setpoint     315720 non-null  float16
#  40  Heating_Temperature_Setpoint                         315720 non-null  float16
#  41  Hot_Water_Flow_Sensor                                315720 non-null  float16
#  42  Hot_Water_Return_Temperature_Sensor                  315720 non-null  float16
#  43  Hot_Water_Supply_Temperature_Sensor                  315720 non-null  float16
#  44  Humidity_Setpoint                                    315720 non-null  float16
#  45  Load_Current_Sensor                                  315720 non-null  float16
#  46  Low_Outside_Air_Temperature_Enable_Setpoint          315720 non-null  float16
#  47  Max_Air_Temperature_Setpoint                         315720 non-null  float16
#  48  Min_Air_Temperature_Setpoint                         315720 non-null  float16
#  49  Outside_Air_CO2_Sensor                               315720 non-null  float16
#  50  Outside_Air_Enthalpy_Sensor                          315720 non-null  float16
#  51  Outside_Air_Humidity_Sensor                          315720 non-null  float16
#  52  Outside_Air_Lockout_Temperature_Setpoint             315720 non-null  float16
#  53  Outside_Air_Temperature_Sensor                       315720 non-null  float16
#  54  Outside_Air_Temperature_Setpoint                     315720 non-null  float16
#  55  Parameter                                            315720 non-null  float16
#  56  Peak_Power_Demand_Sensor                             315720 non-null  float16
#  57  Position_Sensor                                      315720 non-null  float16
#  58  Power_Sensor                                         315720 non-null  float16
#  59  Pressure_Sensor                                      315720 non-null  float16
#  60  Rain_Sensor                                          315720 non-null  float16
#  61  Reactive_Power_Sensor                                315720 non-null  float16
#  62  Reset_Setpoint                                       315720 non-null  float16
#  63  Return_Air_Temperature_Sensor                        315720 non-null  float16
#  64  Return_Water_Temperature_Sensor                      315720 non-null  float16
#  65  Room_Air_Temperature_Setpoint                        315720 non-null  float16
#  66  Sensor                                               315720 non-null  float16
#  67  Setpoint                                             315720 non-null  float16
#  68  Solar_Radiance_Sensor                                315720 non-null  float16
#  69  Speed_Setpoint                                       315720 non-null  float16
#  70  Static_Pressure_Sensor                               315720 non-null  float16
#  71  Static_Pressure_Setpoint                             315720 non-null  float16
#  72  Status                                               315720 non-null  float16
#  73  Supply_Air_Humidity_Sensor                           315720 non-null  float16
#  74  Supply_Air_Static_Pressure_Sensor                    315720 non-null  float16
#  75  Supply_Air_Static_Pressure_Setpoint                  315720 non-null  float16
#  76  Supply_Air_Temperature_Sensor                        315720 non-null  float16
#  77  Supply_Air_Temperature_Setpoint                      315720 non-null  float16
#  78  Temperature_Sensor                                   315720 non-null  float16
#  79  Temperature_Setpoint                                 315720 non-null  float16
#  80  Thermal_Power_Sensor                                 315720 non-null  float16
#  81  Time_Setpoint                                        315720 non-null  float16
#  82  Usage_Sensor                                         315720 non-null  float16
#  83  Valve_Position_Sensor                                315720 non-null  float16
#  84  Voltage_Sensor                                       315720 non-null  float16
#  85  Warmest_Zone_Air_Temperature_Sensor                  315720 non-null  float16
#  86  Water_Flow_Sensor                                    315720 non-null  float16
#  87  Water_Temperature_Sensor                             315720 non-null  float16
#  88  Water_Temperature_Setpoint                           315720 non-null  float16
#  89  Wind_Direction_Sensor                                315720 non-null  float16
#  90  Wind_Speed_Sensor                                    315720 non-null  float16
#  91  Zone_Air_Dewpoint_Sensor                             315720 non-null  float16
#  92  Zone_Air_Humidity_Sensor                             315720 non-null  float16
#  93  Zone_Air_Humidity_Setpoint                           315720 non-null  float16
#  94  Zone_Air_Temperature_Sensor                          315720 non-null  float16
# dtypes: float16(94), object(1)
# memory usage: 59.0+ MB

# %%
# -----------------------------------------------------------
# SAVE THE SUBMISSION FILE
# -----------------------------------------------------------
# Save as a compressed CSV (gzip) without the index column.
submission_file_path = '../data/mr_submission_1.csv.gz'
df_sample.to_csv(submission_file_path, index=False, compression='gzip')
